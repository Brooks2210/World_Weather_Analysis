# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | razole
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | buin
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | shitanjing
# Processing Record 11 of Set 1 | jutai
# Processing Record 12 of Set 1 | franklin
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | ponta do sol
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | nueve de julio
# Processing Record 17 of Set 1 | codrington
# Processing Record 18 of Set 1 | teya
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | yatou
# Processing Record 21 of Set 1 | biak
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | gushikawa
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | shizunai
# Processing Record 27 of Set 1 | imbituba
# Processing Record 28 of Set 1 | akyab
# Processing Record 29 of Set 1 | mokhsogollokh
# Processing Record 30 of Set 1 | krivopolyanye
# City not found. Skipping...
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | hofn
# Processing Record 36 of Set 1 | kununurra
# Processing Record 37 of Set 1 | zlatoustovsk
# City not found. Skipping...
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | poum
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | lauro muller
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | cleethorpes
# Processing Record 45 of Set 1 | port lincoln
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | birao
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | cayenne
# Processing Record 50 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 2 | colac
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | road town
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 2 | ibra
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | galle
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | qaqortoq
# Processing Record 17 of Set 2 | sorland
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | ilo
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | lata
# Processing Record 23 of Set 2 | jizan
# Processing Record 24 of Set 2 | karakol
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | vestmanna
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | teahupoo
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | bilibino
# Processing Record 31 of Set 2 | haines junction
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | moranbah
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | kavaratti
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | hobyo
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | meulaboh
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | tel aviv-yafo
# Processing Record 47 of Set 2 | muswellbrook
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | turukhansk
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | kruisfontein
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | davidson
# Processing Record 5 of Set 3 | lasa
# Processing Record 6 of Set 3 | youkounkoun
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | hirara
# Processing Record 9 of Set 3 | kargasok
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | fare
# Processing Record 12 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 3 | la peca
# Processing Record 14 of Set 3 | sao miguel do araguaia
# Processing Record 15 of Set 3 | atasu
# Processing Record 16 of Set 3 | jardim
# Processing Record 17 of Set 3 | tangara
# Processing Record 18 of Set 3 | bandarbeyla
# Processing Record 19 of Set 3 | sept-iles
# Processing Record 20 of Set 3 | kilindoni
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | sainte-maxime
# Processing Record 24 of Set 3 | kalat
# Processing Record 25 of Set 3 | carnarvon
# Processing Record 26 of Set 3 | andros town
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | vaini
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | sur
# Processing Record 33 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 3 | acarau
# Processing Record 35 of Set 3 | buraydah
# Processing Record 36 of Set 3 | puerto del rosario
# Processing Record 37 of Set 3 | canutama
# Processing Record 38 of Set 3 | banyo
# Processing Record 39 of Set 3 | longyearbyen
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | warrington
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | cap malheureux
# Processing Record 44 of Set 3 | north bend
# Processing Record 45 of Set 3 | bonavista
# Processing Record 46 of Set 3 | victoria point
# Processing Record 47 of Set 3 | manzil tamim
# City not found. Skipping...
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | butaritari
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | mahajanga
# Processing Record 2 of Set 4 | saint-francois
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | sobolevo
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | richards bay
# Processing Record 7 of Set 4 | mitsamiouli
# Processing Record 8 of Set 4 | batamshinskiy
# Processing Record 9 of Set 4 | mehamn
# Processing Record 10 of Set 4 | necochea
# Processing Record 11 of Set 4 | tanete
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 4 | bestobe
# Processing Record 15 of Set 4 | atambua
# Processing Record 16 of Set 4 | syamzha
# Processing Record 17 of Set 4 | high level
# Processing Record 18 of Set 4 | yellowknife
# Processing Record 19 of Set 4 | maneadero
# Processing Record 20 of Set 4 | juneau
# Processing Record 21 of Set 4 | iquitos
# Processing Record 22 of Set 4 | jalu
# Processing Record 23 of Set 4 | praya
# Processing Record 24 of Set 4 | qaanaaq
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | chuguyevka
# Processing Record 27 of Set 4 | beroroha
# Processing Record 28 of Set 4 | lavrentiya
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | trairi
# Processing Record 31 of Set 4 | bethel
# Processing Record 32 of Set 4 | saint-augustin
# Processing Record 33 of Set 4 | aksu
# Processing Record 34 of Set 4 | aparecida do taboado
# Processing Record 35 of Set 4 | honiara
# Processing Record 36 of Set 4 | auki
# Processing Record 37 of Set 4 | paita
# Processing Record 38 of Set 4 | slave lake
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | nanortalik
# Processing Record 41 of Set 4 | svetlaya
# Processing Record 42 of Set 4 | neiafu
# Processing Record 43 of Set 4 | jega
# Processing Record 44 of Set 4 | chulym
# Processing Record 45 of Set 4 | vila franca do campo
# Processing Record 46 of Set 4 | arlit
# Processing Record 47 of Set 4 | phu khieo
# City not found. Skipping...
# Processing Record 48 of Set 4 | springdale
# Processing Record 49 of Set 4 | te anau
# Processing Record 50 of Set 4 | gandiaye
# Processing Record 1 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 5 | burnie
# Processing Record 3 of Set 5 | bodden town
# Processing Record 4 of Set 5 | udachnyy
# Processing Record 5 of Set 5 | nabire
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | lucapa
# Processing Record 8 of Set 5 | marsh harbour
# Processing Record 9 of Set 5 | san policarpo
# Processing Record 10 of Set 5 | san pedro
# Processing Record 11 of Set 5 | sikeston
# Processing Record 12 of Set 5 | juba
# Processing Record 13 of Set 5 | portland
# Processing Record 14 of Set 5 | wenling
# Processing Record 15 of Set 5 | kanniyakumari
# Processing Record 16 of Set 5 | sao filipe
# Processing Record 17 of Set 5 | floro
# Processing Record 18 of Set 5 | itarema
# Processing Record 19 of Set 5 | hambantota
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | ahipara
# Processing Record 22 of Set 5 | paamiut
# Processing Record 23 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 5 | puqi
# Processing Record 25 of Set 5 | saint george
# Processing Record 26 of Set 5 | kuybyshevo
# Processing Record 27 of Set 5 | raudeberg
# Processing Record 28 of Set 5 | shimoda
# Processing Record 29 of Set 5 | lazaro cardenas
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | kolomak
# Processing Record 32 of Set 5 | shingu
# Processing Record 33 of Set 5 | bubaque
# Processing Record 34 of Set 5 | sitka
# Processing Record 35 of Set 5 | port macquarie
# Processing Record 36 of Set 5 | geraldton
# Processing Record 37 of Set 5 | maniitsoq
# Processing Record 38 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 5 | warora
# Processing Record 40 of Set 5 | kualakapuas
# Processing Record 41 of Set 5 | lafia
# Processing Record 42 of Set 5 | medea
# Processing Record 43 of Set 5 | shepsi
# Processing Record 44 of Set 5 | new norfolk
# Processing Record 45 of Set 5 | bambous virieux
# Processing Record 46 of Set 5 | calama
# Processing Record 47 of Set 5 | verkhnetulomskiy
# Processing Record 48 of Set 5 | nam tha
# City not found. Skipping...
# Processing Record 49 of Set 5 | oranjestad
# Processing Record 50 of Set 5 | nadterechnoye
# Processing Record 1 of Set 6 | anjangaon
# Processing Record 2 of Set 6 | gwadar
# Processing Record 3 of Set 6 | khoy
# Processing Record 4 of Set 6 | beisfjord
# Processing Record 5 of Set 6 | kazachinskoye
# Processing Record 6 of Set 6 | mbulu
# Processing Record 7 of Set 6 | havoysund
# Processing Record 8 of Set 6 | lewistown
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | oktyabrskoye
# Processing Record 12 of Set 6 | twin falls
# Processing Record 13 of Set 6 | airai
# Processing Record 14 of Set 6 | lubango
# Processing Record 15 of Set 6 | tilichiki
# Processing Record 16 of Set 6 | togur
# Processing Record 17 of Set 6 | ouallam
# Processing Record 18 of Set 6 | tanabe
# Processing Record 19 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | ulyanovo
# City not found. Skipping...
# Processing Record 22 of Set 6 | churapcha
# Processing Record 23 of Set 6 | aleksandrov gay
# Processing Record 24 of Set 6 | mosquera
# Processing Record 25 of Set 6 | salalah
# Processing Record 26 of Set 6 | ngama
# Processing Record 27 of Set 6 | isangel
# Processing Record 28 of Set 6 | bengkulu
# Processing Record 29 of Set 6 | hasaki
# Processing Record 30 of Set 6 | merauke
# Processing Record 31 of Set 6 | adrar
# Processing Record 32 of Set 6 | hof
# Processing Record 33 of Set 6 | kahului
# Processing Record 34 of Set 6 | walvis bay
# Processing Record 35 of Set 6 | narsaq
# Processing Record 36 of Set 6 | oxapampa
# Processing Record 37 of Set 6 | pundaguitan
# Processing Record 38 of Set 6 | college
# Processing Record 39 of Set 6 | ketchikan
# Processing Record 40 of Set 6 | masvingo
# Processing Record 41 of Set 6 | manokwari
# Processing Record 42 of Set 6 | aasiaat
# Processing Record 43 of Set 6 | flinders
# Processing Record 44 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | makakilo city
# Processing Record 46 of Set 6 | clyde river
# Processing Record 47 of Set 6 | santa cruz
# Processing Record 48 of Set 6 | vao
# Processing Record 49 of Set 6 | nalut
# Processing Record 50 of Set 6 | vitim
# Processing Record 1 of Set 7 | karaton
# Processing Record 2 of Set 7 | wageningen
# Processing Record 3 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 7 | brae
# Processing Record 5 of Set 7 | obera
# Processing Record 6 of Set 7 | nome
# Processing Record 7 of Set 7 | quatre cocos
# Processing Record 8 of Set 7 | saint-louis
# Processing Record 9 of Set 7 | secaria
# Processing Record 10 of Set 7 | la ronge
# Processing Record 11 of Set 7 | at-bashi
# Processing Record 12 of Set 7 | pervomayskiy
# Processing Record 13 of Set 7 | santiago de cuba
# Processing Record 14 of Set 7 | general roca
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | broome
# Processing Record 17 of Set 7 | bukama
# Processing Record 18 of Set 7 | hamilton
# Processing Record 19 of Set 7 | nioro
# Processing Record 20 of Set 7 | bud
# Processing Record 21 of Set 7 | ahuimanu
# Processing Record 22 of Set 7 | novoorsk
# Processing Record 23 of Set 7 | leeton
# Processing Record 24 of Set 7 | port moresby
# Processing Record 25 of Set 7 | beringovskiy
# Processing Record 26 of Set 7 | umarkot
# Processing Record 27 of Set 7 | monte carmelo
# Processing Record 28 of Set 7 | malartic
# Processing Record 29 of Set 7 | wawa
# Processing Record 30 of Set 7 | shache
# Processing Record 31 of Set 7 | novikovo
# Processing Record 32 of Set 7 | deputatskiy
# Processing Record 33 of Set 7 | khandyga
# Processing Record 34 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 7 | teknaf
# Processing Record 36 of Set 7 | surt
# Processing Record 37 of Set 7 | luderitz
# Processing Record 38 of Set 7 | yulara
# Processing Record 39 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 7 | leshukonskoye
# Processing Record 41 of Set 7 | yumen
# Processing Record 42 of Set 7 | hami
# Processing Record 43 of Set 7 | gizo
# Processing Record 44 of Set 7 | verkhnevilyuysk
# Processing Record 45 of Set 7 | bocas del toro
# Processing Record 46 of Set 7 | ixtapa
# Processing Record 47 of Set 7 | ambilobe
# Processing Record 48 of Set 7 | barcelos
# Processing Record 49 of Set 7 | bend
# Processing Record 50 of Set 7 | margate
# Processing Record 1 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 8 | duluth
# Processing Record 3 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 4 of Set 8 | san patricio
# Processing Record 5 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 8 | taksimo
# Processing Record 7 of Set 8 | punta alta
# Processing Record 8 of Set 8 | akdepe
# Processing Record 9 of Set 8 | aklavik
# Processing Record 10 of Set 8 | gasa
# Processing Record 11 of Set 8 | pervoavgustovskiy
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | belaya gora
# Processing Record 14 of Set 8 | piacabucu
# Processing Record 15 of Set 8 | moose factory
# Processing Record 16 of Set 8 | coari
# Processing Record 17 of Set 8 | leningradskiy
# Processing Record 18 of Set 8 | fort nelson
# Processing Record 19 of Set 8 | uwajima
# Processing Record 20 of Set 8 | casper
# Processing Record 21 of Set 8 | kiruna
# Processing Record 22 of Set 8 | bhinmal
# Processing Record 23 of Set 8 | northam
# Processing Record 24 of Set 8 | lunavada
# Processing Record 25 of Set 8 | cheney
# Processing Record 26 of Set 8 | kintampo
# Processing Record 27 of Set 8 | garhshankar
# Processing Record 28 of Set 8 | cascais
# Processing Record 29 of Set 8 | mildura
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | becerril
# Processing Record 32 of Set 8 | puerto quijarro
# Processing Record 33 of Set 8 | dingle
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | beaverlodge
# Processing Record 36 of Set 8 | katsuura
# Processing Record 37 of Set 8 | la macarena
# Processing Record 38 of Set 8 | carutapera
# Processing Record 39 of Set 8 | talara
# Processing Record 40 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 8 | atar
# Processing Record 42 of Set 8 | tiksi
# Processing Record 43 of Set 8 | oriximina
# Processing Record 44 of Set 8 | riyadh
# Processing Record 45 of Set 8 | hun
# Processing Record 46 of Set 8 | ust-kut
# Processing Record 47 of Set 8 | saint paul
# Processing Record 48 of Set 8 | aswan
# Processing Record 49 of Set 8 | iracoubo
# Processing Record 50 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 9 | inuvik
# Processing Record 2 of Set 9 | honningsvag
# Processing Record 3 of Set 9 | kalnciems
# Processing Record 4 of Set 9 | lashio
# Processing Record 5 of Set 9 | sola
# Processing Record 6 of Set 9 | fortuna
# Processing Record 7 of Set 9 | yerbogachen
# Processing Record 8 of Set 9 | merrill
# Processing Record 9 of Set 9 | touba
# Processing Record 10 of Set 9 | kulhudhuffushi
# Processing Record 11 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 12 of Set 9 | stornoway
# Processing Record 13 of Set 9 | brownwood
# Processing Record 14 of Set 9 | anshun
# Processing Record 15 of Set 9 | san jeronimo
# Processing Record 16 of Set 9 | omboue
# Processing Record 17 of Set 9 | baie-comeau
# Processing Record 18 of Set 9 | impfondo
# Processing Record 19 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 9 | kodinsk
# Processing Record 21 of Set 9 | humberto de campos
# Processing Record 22 of Set 9 | albox
# Processing Record 23 of Set 9 | saint-georges
# Processing Record 24 of Set 9 | coquimbo
# Processing Record 25 of Set 9 | vila velha
# Processing Record 26 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 9 | la reforma
# Processing Record 28 of Set 9 | port arthur
# Processing Record 29 of Set 9 | malakal
# Processing Record 30 of Set 9 | amga
# Processing Record 31 of Set 9 | luwuk
# Processing Record 32 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 33 of Set 9 | trujillo
# Processing Record 34 of Set 9 | san andres
# Processing Record 35 of Set 9 | muros
# Processing Record 36 of Set 9 | port hardy
# Processing Record 37 of Set 9 | shaunavon
# Processing Record 38 of Set 9 | sao joao da barra
# Processing Record 39 of Set 9 | tecoanapa
# Processing Record 40 of Set 9 | shaoyang
# Processing Record 41 of Set 9 | thessalon
# Processing Record 42 of Set 9 | mitu
# Processing Record 43 of Set 9 | houma
# Processing Record 44 of Set 9 | pangnirtung
# Processing Record 45 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 9 | henties bay
# Processing Record 47 of Set 9 | tiruppuvanam
# Processing Record 48 of Set 9 | khuzhir
# Processing Record 49 of Set 9 | tura
# Processing Record 50 of Set 9 | tutoia
# Processing Record 1 of Set 10 | ostrovnoy
# Processing Record 2 of Set 10 | najran
# Processing Record 3 of Set 10 | oranjemund
# Processing Record 4 of Set 10 | coolum beach
# Processing Record 5 of Set 10 | namibe
# Processing Record 6 of Set 10 | tucuman
# Processing Record 7 of Set 10 | monrovia
# Processing Record 8 of Set 10 | los llanos de aridane
# Processing Record 9 of Set 10 | puerto narino
# Processing Record 10 of Set 10 | pritzwalk
# Processing Record 11 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 10 | lorengau
# Processing Record 13 of Set 10 | svetlyy
# Processing Record 14 of Set 10 | ampanihy
# Processing Record 15 of Set 10 | kimbe
# Processing Record 16 of Set 10 | west wendover
# Processing Record 17 of Set 10 | naze
# Processing Record 18 of Set 10 | cockburn town
# Processing Record 19 of Set 10 | aquin
# Processing Record 20 of Set 10 | turayf
# Processing Record 21 of Set 10 | bambui
# Processing Record 22 of Set 10 | mezen
# Processing Record 23 of Set 10 | ekhabi
# Processing Record 24 of Set 10 | panguna
# Processing Record 25 of Set 10 | lagoa
# Processing Record 26 of Set 10 | terney
# Processing Record 27 of Set 10 | rawson
# Processing Record 28 of Set 10 | san cristobal
# Processing Record 29 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 30 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 32 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 10 | viile satu mare
# Processing Record 34 of Set 10 | sparks
# Processing Record 35 of Set 10 | tymovskoye
# Processing Record 36 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 10 | tabas
# Processing Record 38 of Set 10 | creel
# Processing Record 39 of Set 10 | baruun-urt
# Processing Record 40 of Set 10 | husavik
# Processing Record 41 of Set 10 | inhambane
# Processing Record 42 of Set 10 | lira
# Processing Record 43 of Set 10 | chachoengsao
# Processing Record 44 of Set 10 | bellavista
# Processing Record 45 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 46 of Set 10 | clarksburg
# Processing Record 47 of Set 10 | olafsvik
# Processing Record 48 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 49 of Set 10 | west fargo
# Processing Record 50 of Set 10 | ulety
# Processing Record 1 of Set 11 | katobu
# Processing Record 2 of Set 11 | guayaramerin
# Processing Record 3 of Set 11 | roma
# Processing Record 4 of Set 11 | svetlogorsk
# Processing Record 5 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 6 of Set 11 | chumikan
# Processing Record 7 of Set 11 | la grande
# Processing Record 8 of Set 11 | rancho palos verdes
# Processing Record 9 of Set 11 | ardakan
# Processing Record 10 of Set 11 | araouane
# Processing Record 11 of Set 11 | dicabisagan
# Processing Record 12 of Set 11 | zuya
# Processing Record 13 of Set 11 | alice springs
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | touros
# Processing Record 16 of Set 11 | lensk
# Processing Record 17 of Set 11 | ukiah
# Processing Record 18 of Set 11 | christchurch
# Processing Record 19 of Set 11 | atocha
# Processing Record 20 of Set 11 | moron
# Processing Record 21 of Set 11 | laukaa
# Processing Record 22 of Set 11 | tayu
# Processing Record 23 of Set 11 | conakry
# Processing Record 24 of Set 11 | laguna
# Processing Record 25 of Set 11 | kunya
# Processing Record 26 of Set 11 | saint anthony
# Processing Record 27 of Set 11 | ostersund
# Processing Record 28 of Set 11 | lebanon
# Processing Record 29 of Set 11 | sao jose da coroa grande
# Processing Record 30 of Set 11 | umea
# Processing Record 31 of Set 11 | arraias
# Processing Record 32 of Set 11 | glazov
# Processing Record 33 of Set 11 | loandjili
# Processing Record 34 of Set 11 | seymchan
# Processing Record 35 of Set 11 | boffa
# Processing Record 36 of Set 11 | alofi
# Processing Record 37 of Set 11 | tezu
# Processing Record 38 of Set 11 | goderich
# Processing Record 39 of Set 11 | rognan
# Processing Record 40 of Set 11 | ilulissat
# Processing Record 41 of Set 11 | sinnamary
# Processing Record 42 of Set 11 | toktogul
# Processing Record 43 of Set 11 | venado
# Processing Record 44 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 11 | morges
# Processing Record 46 of Set 11 | ridgecrest
# Processing Record 47 of Set 11 | soni
# Processing Record 48 of Set 11 | acajutla
# Processing Record 49 of Set 11 | klaksvik
# Processing Record 50 of Set 11 | curuca
# Processing Record 1 of Set 12 | jaipur hat
# City not found. Skipping...
# Processing Record 2 of Set 12 | paramonga
# Processing Record 3 of Set 12 | kaoma
# Processing Record 4 of Set 12 | gogrial
# Processing Record 5 of Set 12 | ponta delgada
# Processing Record 6 of Set 12 | springbok
# Processing Record 7 of Set 12 | guerrero negro
# Processing Record 8 of Set 12 | asgabat
# Processing Record 9 of Set 12 | tual
# Processing Record 10 of Set 12 | aguimes
# Processing Record 11 of Set 12 | fairbanks
# Processing Record 12 of Set 12 | gladstone
# Processing Record 13 of Set 12 | sumenep
# Processing Record 14 of Set 12 | sabang
# Processing Record 15 of Set 12 | egvekinot
# Processing Record 16 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 17 of Set 12 | carballo
# Processing Record 18 of Set 12 | lincoln
# Processing Record 19 of Set 12 | vernon
# Processing Record 20 of Set 12 | partizanskoye
# Processing Record 21 of Set 12 | mossendjo
# Processing Record 22 of Set 12 | karacabey
# Processing Record 23 of Set 12 | maarianhamina
# Processing Record 24 of Set 12 | kirkuk
# Processing Record 25 of Set 12 | bafq
# Processing Record 26 of Set 12 | tonstad
# Processing Record 27 of Set 12 | do gonbadan
# Processing Record 28 of Set 12 | terrak
# Processing Record 29 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 30 of Set 12 | souillac
# Processing Record 31 of Set 12 | celestun
# Processing Record 32 of Set 12 | caravelas
# Processing Record 33 of Set 12 | atlantic city
# Processing Record 34 of Set 12 | boguchany
# Processing Record 35 of Set 12 | itaituba
# Processing Record 36 of Set 12 | arua
# Processing Record 37 of Set 12 | barras
# Processing Record 38 of Set 12 | saint-joseph
# Processing Record 39 of Set 12 | huittinen
# Processing Record 40 of Set 12 | macaparana
# Processing Record 41 of Set 12 | inirida
# Processing Record 42 of Set 12 | hovd
# Processing Record 43 of Set 12 | palmares
# Processing Record 44 of Set 12 | waingapu
# Processing Record 45 of Set 12 | petauke
# Processing Record 46 of Set 12 | harigue
# City not found. Skipping...
# Processing Record 47 of Set 12 | praia da vitoria
# Processing Record 48 of Set 12 | takoradi
# Processing Record 49 of Set 12 | tessalit
# Processing Record 50 of Set 12 | youghal
# Processing Record 1 of Set 13 | mazagao
# Processing Record 2 of Set 13 | benin
# Processing Record 3 of Set 13 | sao domingos do maranhao
# Processing Record 4 of Set 13 | rincon
# Processing Record 5 of Set 13 | flin flon
# Processing Record 6 of Set 13 | tynda
# Processing Record 7 of Set 13 | qandala
# Processing Record 8 of Set 13 | berlevag
# Processing Record 9 of Set 13 | finschhafen
# Processing Record 10 of Set 13 | kharan
# Processing Record 11 of Set 13 | aromashevo
# Processing Record 12 of Set 13 | kropotkin
# Processing Record 13 of Set 13 | veraval
# Processing Record 14 of Set 13 | aflu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 557

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     51.80        50           0
# 1       Rikitea -23.1203 -134.9692     80.31        68           2
# 2     Tuatapere -46.1333  167.6833     60.01        84          99
# 3        Dikson  73.5069   80.5464    -15.41        89         100
# 4        Razole  16.4833   81.8333     64.89        93          18
# 5    Kaitangata -46.2817  169.8464     64.00        62          92
# 6          Buin -33.7333  -70.7500     84.00        41           0
# 7        Barrow  71.2906 -156.7887     -5.80        77           1
# 8    Shitanjing  39.2342  106.3439     20.44        84          29
# 9         Jutai  -5.1833  -68.9000     74.43        94          96
#
#    Wind Speed Country                 Date
# 0       25.32      CL  2021-01-24 23:30:22
# 1       10.38      PF  2021-01-24 23:30:23
# 2       21.00      NZ  2021-01-24 23:30:23
# 3       12.17      RU  2021-01-24 23:30:23
# 4        2.55      IN  2021-01-24 23:30:23
# 5       20.00      NZ  2021-01-24 23:30:23
# 6        6.91      CL  2021-01-24 23:30:24
# 7       11.50      US  2021-01-24 23:30:24
# 8       10.20      CN  2021-01-24 23:30:24
# 9        1.10      BR  2021-01-24 23:30:24

# %%
new_column_order = ["City", "Country", "Date","Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Punta Arenas      CL  2021-01-24 23:30:22 -53.1500  -70.9167     51.80
# 1       Rikitea      PF  2021-01-24 23:30:23 -23.1203 -134.9692     80.31
# 2     Tuatapere      NZ  2021-01-24 23:30:23 -46.1333  167.6833     60.01
# 3        Dikson      RU  2021-01-24 23:30:23  73.5069   80.5464    -15.41
# 4        Razole      IN  2021-01-24 23:30:23  16.4833   81.8333     64.89
# 5    Kaitangata      NZ  2021-01-24 23:30:23 -46.2817  169.8464     64.00
# 6          Buin      CL  2021-01-24 23:30:24 -33.7333  -70.7500     84.00
# 7        Barrow      US  2021-01-24 23:30:24  71.2906 -156.7887     -5.80
# 8    Shitanjing      CN  2021-01-24 23:30:24  39.2342  106.3439     20.44
# 9         Jutai      BR  2021-01-24 23:30:24  -5.1833  -68.9000     74.43
#
#    Humidity  Cloudiness  Wind Speed
# 0        50           0       25.32
# 1        68           2       10.38
# 2        84          99       21.00
# 3        89         100       12.17
# 4        93          18        2.55
# 5        62          92       20.00
# 6        41           0        6.91
# 7        77           1       11.50
# 8        84          29       10.20
# 9        94          96        1.10

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                         Hilo
# Country                        US
# Date          2021-01-24 23:30:26
# Lat                       19.7297
# Lng                       -155.09
# Max Temp                     78.8
# Humidity                       65
# Cloudiness                     40
# Wind Speed                   6.91
# Name: 13, dtype: object

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 3       Dikson      RU  2021-01-24 23:30:23  73.5069   80.5464    -15.41
# 4       Razole      IN  2021-01-24 23:30:23  16.4833   81.8333     64.89
# 7       Barrow      US  2021-01-24 23:30:24  71.2906 -156.7887     -5.80
# 8   Shitanjing      CN  2021-01-24 23:30:24  39.2342  106.3439     20.44
# 10    Franklin      US  2021-01-24 23:30:24  39.9667  -83.0166     28.40
#
#     Humidity  Cloudiness  Wind Speed
# 3         89         100       12.17
# 4         93          18        2.55
# 7         77           1       11.50
# 8         84          29       10.20
# 10        93          90        6.91

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,-20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,30))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,25))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', 'Cloudiness',(40,10))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', 'Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,25))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,20))

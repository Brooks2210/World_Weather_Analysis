# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | kanigoro
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | vesoul
# Processing Record 7 of Set 1 | lincoln
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | mpulungu
# Processing Record 11 of Set 1 | ekibastuz
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | warrington
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | bol
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | tezu
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | mandalgovi
# Processing Record 25 of Set 1 | haapu
# City not found. Skipping...
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | mitsamiouli
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | moose factory
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | vilhena
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | souillac
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | sola
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | innisfail
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | peniche
# Processing Record 45 of Set 1 | mount gambier
# Processing Record 46 of Set 1 | kruisfontein
# Processing Record 47 of Set 1 | kolosovka
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | dumbea
# Processing Record 50 of Set 1 | rehoboth
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | saint-augustin
# Processing Record 3 of Set 2 | provideniya
# Processing Record 4 of Set 2 | andros town
# Processing Record 5 of Set 2 | muisne
# Processing Record 6 of Set 2 | hofn
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | tilichiki
# Processing Record 9 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | kalmunai
# Processing Record 11 of Set 2 | misratah
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | bambous virieux
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | nemuro
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | maniitsoq
# Processing Record 19 of Set 2 | sabha
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | palmer
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | mvomero
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | half moon bay
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | pundaguitan
# Processing Record 30 of Set 2 | kyra
# Processing Record 31 of Set 2 | leningradskiy
# Processing Record 32 of Set 2 | kieta
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | sumbawanga
# Processing Record 36 of Set 2 | pochutla
# Processing Record 37 of Set 2 | kaoma
# Processing Record 38 of Set 2 | port lincoln
# Processing Record 39 of Set 2 | meadow lake
# Processing Record 40 of Set 2 | progreso
# Processing Record 41 of Set 2 | inhambane
# Processing Record 42 of Set 2 | pop
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | we
# City not found. Skipping...
# Processing Record 46 of Set 2 | aromashevo
# Processing Record 47 of Set 2 | west bend
# Processing Record 48 of Set 2 | shuangyang
# Processing Record 49 of Set 2 | olinda
# Processing Record 50 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 3 | iracoubo
# Processing Record 2 of Set 3 | kuala kangsar
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | talisay
# Processing Record 5 of Set 3 | puntarenas
# Processing Record 6 of Set 3 | viedma
# Processing Record 7 of Set 3 | manuk mangkaw
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | college
# Processing Record 10 of Set 3 | kamenka
# Processing Record 11 of Set 3 | el carrizo
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | ponta delgada
# Processing Record 15 of Set 3 | lompoc
# Processing Record 16 of Set 3 | abha
# Processing Record 17 of Set 3 | oranjemund
# Processing Record 18 of Set 3 | arlit
# Processing Record 19 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 3 | yerbogachen
# Processing Record 21 of Set 3 | tromso
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | bathsheba
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | nishihara
# Processing Record 27 of Set 3 | pismo beach
# Processing Record 28 of Set 3 | gat
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | cabedelo
# Processing Record 31 of Set 3 | faya
# Processing Record 32 of Set 3 | tual
# Processing Record 33 of Set 3 | haines junction
# Processing Record 34 of Set 3 | kudahuvadhoo
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | kadnikov
# Processing Record 37 of Set 3 | westport
# Processing Record 38 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 3 | inirida
# Processing Record 40 of Set 3 | pyu
# Processing Record 41 of Set 3 | vidim
# Processing Record 42 of Set 3 | panzhihua
# Processing Record 43 of Set 3 | te anau
# Processing Record 44 of Set 3 | kargasok
# Processing Record 45 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 3 | shimoda
# Processing Record 48 of Set 3 | tecoanapa
# Processing Record 49 of Set 3 | lahaina
# Processing Record 50 of Set 3 | burica
# City not found. Skipping...
# Processing Record 1 of Set 4 | bull savanna
# Processing Record 2 of Set 4 | hede
# Processing Record 3 of Set 4 | guariba
# Processing Record 4 of Set 4 | vaini
# Processing Record 5 of Set 4 | butaritari
# Processing Record 6 of Set 4 | kenai
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | salvador
# Processing Record 9 of Set 4 | zhangye
# Processing Record 10 of Set 4 | ternate
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | pisco
# Processing Record 14 of Set 4 | arcata
# Processing Record 15 of Set 4 | mandera
# Processing Record 16 of Set 4 | sao filipe
# Processing Record 17 of Set 4 | tigil
# Processing Record 18 of Set 4 | margate
# Processing Record 19 of Set 4 | palana
# Processing Record 20 of Set 4 | zharkent
# Processing Record 21 of Set 4 | aksu
# Processing Record 22 of Set 4 | dhidhdhoo
# Processing Record 23 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 4 | leninogorsk
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | angoche
# Processing Record 27 of Set 4 | mildura
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | maiduguri
# Processing Record 30 of Set 4 | laguna
# Processing Record 31 of Set 4 | rawson
# Processing Record 32 of Set 4 | longyearbyen
# Processing Record 33 of Set 4 | saint-philippe
# Processing Record 34 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 4 | ulaangom
# Processing Record 36 of Set 4 | konskie
# Processing Record 37 of Set 4 | porto novo
# Processing Record 38 of Set 4 | carbonear
# Processing Record 39 of Set 4 | riviere-au-renard
# Processing Record 40 of Set 4 | khilok
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | azare
# Processing Record 43 of Set 4 | majene
# Processing Record 44 of Set 4 | dunmore town
# Processing Record 45 of Set 4 | bosaso
# Processing Record 46 of Set 4 | tuy hoa
# Processing Record 47 of Set 4 | karlshamn
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | ahuimanu
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 3 of Set 5 | lobito
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | marsabit
# Processing Record 6 of Set 5 | norman wells
# Processing Record 7 of Set 5 | kunya
# Processing Record 8 of Set 5 | hobart
# Processing Record 9 of Set 5 | iqaluit
# Processing Record 10 of Set 5 | ustka
# Processing Record 11 of Set 5 | codrington
# Processing Record 12 of Set 5 | sur
# Processing Record 13 of Set 5 | meulaboh
# Processing Record 14 of Set 5 | kommunisticheskiy
# Processing Record 15 of Set 5 | tsabong
# Processing Record 16 of Set 5 | tommot
# Processing Record 17 of Set 5 | georgiyevka
# Processing Record 18 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 19 of Set 5 | sioux lookout
# Processing Record 20 of Set 5 | shelburne
# Processing Record 21 of Set 5 | constitucion
# Processing Record 22 of Set 5 | nkhotakota
# Processing Record 23 of Set 5 | guerrero negro
# Processing Record 24 of Set 5 | miles city
# Processing Record 25 of Set 5 | yulara
# Processing Record 26 of Set 5 | forecariah
# Processing Record 27 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 5 | la palma
# Processing Record 29 of Set 5 | florence
# Processing Record 30 of Set 5 | aklavik
# Processing Record 31 of Set 5 | vila velha
# Processing Record 32 of Set 5 | padang
# Processing Record 33 of Set 5 | shenzhen
# Processing Record 34 of Set 5 | narsaq
# Processing Record 35 of Set 5 | dehloran
# Processing Record 36 of Set 5 | ixtapa
# Processing Record 37 of Set 5 | esperance
# Processing Record 38 of Set 5 | wellington
# Processing Record 39 of Set 5 | davidson
# Processing Record 40 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 5 | orange cove
# Processing Record 42 of Set 5 | chivacoa
# Processing Record 43 of Set 5 | evensk
# Processing Record 44 of Set 5 | tessalit
# Processing Record 45 of Set 5 | ambovombe
# Processing Record 46 of Set 5 | kodiak
# Processing Record 47 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 5 | kavaratti
# Processing Record 49 of Set 5 | dingle
# Processing Record 50 of Set 5 | nuuk
# Processing Record 1 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 2 of Set 6 | goderich
# Processing Record 3 of Set 6 | juneau
# Processing Record 4 of Set 6 | pascagoula
# Processing Record 5 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 6 | huadian
# Processing Record 7 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 6 | paamiut
# Processing Record 9 of Set 6 | imbituba
# Processing Record 10 of Set 6 | hay river
# Processing Record 11 of Set 6 | gorontalo
# Processing Record 12 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 6 | omboue
# Processing Record 14 of Set 6 | tenabo
# Processing Record 15 of Set 6 | suntar
# Processing Record 16 of Set 6 | tuktoyaktuk
# Processing Record 17 of Set 6 | puerto escondido
# Processing Record 18 of Set 6 | beringovskiy
# Processing Record 19 of Set 6 | fomboni
# Processing Record 20 of Set 6 | richards bay
# Processing Record 21 of Set 6 | minden
# Processing Record 22 of Set 6 | rome
# Processing Record 23 of Set 6 | cidreira
# Processing Record 24 of Set 6 | kantunilkin
# Processing Record 25 of Set 6 | jamestown
# Processing Record 26 of Set 6 | plettenberg bay
# Processing Record 27 of Set 6 | cambridge
# Processing Record 28 of Set 6 | poum
# Processing Record 29 of Set 6 | bengkulu
# Processing Record 30 of Set 6 | buy
# Processing Record 31 of Set 6 | silver city
# Processing Record 32 of Set 6 | olafsvik
# Processing Record 33 of Set 6 | mackay
# Processing Record 34 of Set 6 | bilma
# Processing Record 35 of Set 6 | san luis obispo
# Processing Record 36 of Set 6 | waddan
# Processing Record 37 of Set 6 | deputatskiy
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | coihaique
# Processing Record 40 of Set 6 | najran
# Processing Record 41 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 42 of Set 6 | necochea
# Processing Record 43 of Set 6 | chernigovka
# Processing Record 44 of Set 6 | georgetown
# Processing Record 45 of Set 6 | cadillac
# Processing Record 46 of Set 6 | karasjok
# Processing Record 47 of Set 6 | salalah
# Processing Record 48 of Set 6 | vila do maio
# Processing Record 49 of Set 6 | teguldet
# Processing Record 50 of Set 6 | sitka
# Processing Record 1 of Set 7 | cockburn town
# Processing Record 2 of Set 7 | madisonville
# Processing Record 3 of Set 7 | novopokrovka
# Processing Record 4 of Set 7 | moree
# Processing Record 5 of Set 7 | hilton head island
# Processing Record 6 of Set 7 | port hawkesbury
# Processing Record 7 of Set 7 | coracora
# Processing Record 8 of Set 7 | dunedin
# Processing Record 9 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 7 | coahuayana
# Processing Record 11 of Set 7 | labuan
# Processing Record 12 of Set 7 | husavik
# Processing Record 13 of Set 7 | harlow
# Processing Record 14 of Set 7 | lovozero
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 7 | puerto colombia
# Processing Record 18 of Set 7 | alibag
# Processing Record 19 of Set 7 | uberaba
# Processing Record 20 of Set 7 | henties bay
# Processing Record 21 of Set 7 | celestun
# Processing Record 22 of Set 7 | honiara
# Processing Record 23 of Set 7 | nichinan
# Processing Record 24 of Set 7 | praia
# Processing Record 25 of Set 7 | worland
# Processing Record 26 of Set 7 | havoysund
# Processing Record 27 of Set 7 | qaqortoq
# Processing Record 28 of Set 7 | cikupa
# Processing Record 29 of Set 7 | khovu-aksy
# Processing Record 30 of Set 7 | pangoa
# Processing Record 31 of Set 7 | tonantins
# Processing Record 32 of Set 7 | kangaatsiaq
# Processing Record 33 of Set 7 | edd
# Processing Record 34 of Set 7 | chippewa falls
# Processing Record 35 of Set 7 | beyneu
# Processing Record 36 of Set 7 | skowhegan
# Processing Record 37 of Set 7 | roma
# Processing Record 38 of Set 7 | flin flon
# Processing Record 39 of Set 7 | fairbanks
# Processing Record 40 of Set 7 | khani
# Processing Record 41 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 7 | chilliwack
# Processing Record 43 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 7 | charlestown
# Processing Record 45 of Set 7 | hamilton
# Processing Record 46 of Set 7 | port shepstone
# Processing Record 47 of Set 7 | forestville
# Processing Record 48 of Set 7 | broken hill
# Processing Record 49 of Set 7 | dahuk
# Processing Record 50 of Set 7 | kralendijk
# Processing Record 1 of Set 8 | sinfra
# Processing Record 2 of Set 8 | ancud
# Processing Record 3 of Set 8 | flinders
# Processing Record 4 of Set 8 | ugoofaaru
# Processing Record 5 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 8 | jasper
# Processing Record 7 of Set 8 | atar
# Processing Record 8 of Set 8 | luderitz
# Processing Record 9 of Set 8 | batagay-alyta
# Processing Record 10 of Set 8 | ladario
# Processing Record 11 of Set 8 | aswan
# Processing Record 12 of Set 8 | mersing
# Processing Record 13 of Set 8 | centralia
# Processing Record 14 of Set 8 | mwinilunga
# Processing Record 15 of Set 8 | isangel
# Processing Record 16 of Set 8 | marzuq
# Processing Record 17 of Set 8 | rio gallegos
# Processing Record 18 of Set 8 | atambua
# Processing Record 19 of Set 8 | bandarbeyla
# Processing Record 20 of Set 8 | lyubim
# Processing Record 21 of Set 8 | fallon
# Processing Record 22 of Set 8 | salinopolis
# Processing Record 23 of Set 8 | machico
# Processing Record 24 of Set 8 | aykhal
# Processing Record 25 of Set 8 | kysyl-syr
# Processing Record 26 of Set 8 | vila praia de ancora
# Processing Record 27 of Set 8 | antigonish
# Processing Record 28 of Set 8 | nizhniy baskunchak
# Processing Record 29 of Set 8 | nouadhibou
# Processing Record 30 of Set 8 | bonavista
# Processing Record 31 of Set 8 | lisala
# Processing Record 32 of Set 8 | buala
# Processing Record 33 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | kasane
# Processing Record 36 of Set 8 | wanaka
# Processing Record 37 of Set 8 | orasac
# Processing Record 38 of Set 8 | mitu
# Processing Record 39 of Set 8 | hovd
# Processing Record 40 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 8 | taoudenni
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | berlevag
# Processing Record 44 of Set 8 | leshukonskoye
# Processing Record 45 of Set 8 | sunland park
# Processing Record 46 of Set 8 | kloulklubed
# Processing Record 47 of Set 8 | kizema
# Processing Record 48 of Set 8 | lagoa
# Processing Record 49 of Set 8 | taonan
# Processing Record 50 of Set 8 | morondava
# Processing Record 1 of Set 9 | shitanjing
# Processing Record 2 of Set 9 | palafrugell
# Processing Record 3 of Set 9 | along
# Processing Record 4 of Set 9 | ramgarh
# Processing Record 5 of Set 9 | fort nelson
# Processing Record 6 of Set 9 | almaznyy
# Processing Record 7 of Set 9 | nieuw amsterdam
# Processing Record 8 of Set 9 | parambu
# Processing Record 9 of Set 9 | charters towers
# Processing Record 10 of Set 9 | kathu
# Processing Record 11 of Set 9 | vorukh
# Processing Record 12 of Set 9 | kaeo
# Processing Record 13 of Set 9 | ostrovnoy
# Processing Record 14 of Set 9 | airai
# Processing Record 15 of Set 9 | bafq
# Processing Record 16 of Set 9 | ariquemes
# Processing Record 17 of Set 9 | nhamunda
# Processing Record 18 of Set 9 | zhezkazgan
# Processing Record 19 of Set 9 | anadyr
# Processing Record 20 of Set 9 | shahrud
# Processing Record 21 of Set 9 | reconquista
# Processing Record 22 of Set 9 | talnakh
# Processing Record 23 of Set 9 | kuressaare
# Processing Record 24 of Set 9 | walvis bay
# Processing Record 25 of Set 9 | norrtalje
# Processing Record 26 of Set 9 | mahenge
# Processing Record 27 of Set 9 | magdalena
# Processing Record 28 of Set 9 | fortuna
# Processing Record 29 of Set 9 | namibe
# Processing Record 30 of Set 9 | mangan
# Processing Record 31 of Set 9 | clyde river
# Processing Record 32 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 33 of Set 9 | bogorodskoye
# Processing Record 34 of Set 9 | igrim
# Processing Record 35 of Set 9 | polyarnyy
# Processing Record 36 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 37 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 9 | portland
# Processing Record 39 of Set 9 | luan
# Processing Record 40 of Set 9 | nkoteng
# Processing Record 41 of Set 9 | vaitape
# Processing Record 42 of Set 9 | taguatinga
# Processing Record 43 of Set 9 | akhtubinsk
# Processing Record 44 of Set 9 | caravelas
# Processing Record 45 of Set 9 | kilindoni
# Processing Record 46 of Set 9 | diapaga
# Processing Record 47 of Set 9 | vanavara
# Processing Record 48 of Set 9 | ust-tsilma
# Processing Record 49 of Set 9 | kismayo
# Processing Record 50 of Set 9 | madimba
# Processing Record 1 of Set 10 | superior
# Processing Record 2 of Set 10 | keti bandar
# Processing Record 3 of Set 10 | borgarnes
# Processing Record 4 of Set 10 | tucuma
# Processing Record 5 of Set 10 | rapid valley
# Processing Record 6 of Set 10 | mogadishu
# Processing Record 7 of Set 10 | lorica
# Processing Record 8 of Set 10 | campobello di mazara
# Processing Record 9 of Set 10 | fort smith
# Processing Record 10 of Set 10 | empalme
# Processing Record 11 of Set 10 | achacachi
# Processing Record 12 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 13 of Set 10 | omsukchan
# Processing Record 14 of Set 10 | coquimbo
# Processing Record 15 of Set 10 | nadadores
# Processing Record 16 of Set 10 | samarai
# Processing Record 17 of Set 10 | kaya
# Processing Record 18 of Set 10 | solnechnyy
# Processing Record 19 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 10 | astara
# Processing Record 21 of Set 10 | shingu
# Processing Record 22 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 10 | kathmandu
# Processing Record 25 of Set 10 | giyani
# Processing Record 26 of Set 10 | sumbe
# Processing Record 27 of Set 10 | kununurra
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | krasnoselkup
# Processing Record 30 of Set 10 | iwanai
# Processing Record 31 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 10 | anito
# Processing Record 33 of Set 10 | tuatapere
# Processing Record 34 of Set 10 | moron
# Processing Record 35 of Set 10 | san rafael del sur
# Processing Record 36 of Set 10 | saint-joseph
# Processing Record 37 of Set 10 | yuli
# Processing Record 38 of Set 10 | kapuskasing
# Processing Record 39 of Set 10 | korla
# Processing Record 40 of Set 10 | emba
# Processing Record 41 of Set 10 | selishche
# Processing Record 42 of Set 10 | banda aceh
# Processing Record 43 of Set 10 | port pirie
# Processing Record 44 of Set 10 | hokitika
# Processing Record 45 of Set 10 | kamaishi
# Processing Record 46 of Set 10 | machali
# Processing Record 47 of Set 10 | chubbuck
# Processing Record 48 of Set 10 | antofagasta
# Processing Record 49 of Set 10 | bedesa
# Processing Record 50 of Set 10 | benjamin constant
# Processing Record 1 of Set 11 | oksfjord
# Processing Record 2 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 3 of Set 11 | amahai
# Processing Record 4 of Set 11 | klyuchi
# Processing Record 5 of Set 11 | pecos
# Processing Record 6 of Set 11 | vidalia
# Processing Record 7 of Set 11 | mezen
# Processing Record 8 of Set 11 | comodoro rivadavia
# Processing Record 9 of Set 11 | matagami
# Processing Record 10 of Set 11 | miracema do tocantins
# Processing Record 11 of Set 11 | morlaix
# Processing Record 12 of Set 11 | nelson bay
# Processing Record 13 of Set 11 | marion
# Processing Record 14 of Set 11 | kyzyl-suu
# Processing Record 15 of Set 11 | nicoya
# Processing Record 16 of Set 11 | russell
# Processing Record 17 of Set 11 | sabang
# Processing Record 18 of Set 11 | alofi
# Processing Record 19 of Set 11 | fierze
# City not found. Skipping...
# Processing Record 20 of Set 11 | mnogovershinnyy
# Processing Record 21 of Set 11 | maumere
# Processing Record 22 of Set 11 | kot putli
# City not found. Skipping...
# Processing Record 23 of Set 11 | san jeronimo
# Processing Record 24 of Set 11 | merzifon
# Processing Record 25 of Set 11 | qurayyat
# Processing Record 26 of Set 11 | hasaki
# Processing Record 27 of Set 11 | ust-nera
# Processing Record 28 of Set 11 | kargil
# Processing Record 29 of Set 11 | opuwo
# Processing Record 30 of Set 11 | oum hadjer
# Processing Record 31 of Set 11 | saldanha
# Processing Record 32 of Set 11 | itarema
# Processing Record 33 of Set 11 | tawzar
# City not found. Skipping...
# Processing Record 34 of Set 11 | araouane
# Processing Record 35 of Set 11 | acapulco
# Processing Record 36 of Set 11 | dzilam gonzalez
# Processing Record 37 of Set 11 | neuquen
# Processing Record 38 of Set 11 | burns lake
# Processing Record 39 of Set 11 | abbeyfeale
# Processing Record 40 of Set 11 | moranbah
# Processing Record 41 of Set 11 | villamontes
# Processing Record 42 of Set 11 | vestmannaeyjar
# Processing Record 43 of Set 11 | banyo
# Processing Record 44 of Set 11 | kovdor
# Processing Record 45 of Set 11 | manokwari
# Processing Record 46 of Set 11 | segezha
# Processing Record 47 of Set 11 | paldiski
# Processing Record 48 of Set 11 | duncan
# Processing Record 49 of Set 11 | lyubeshiv
# City not found. Skipping...
# Processing Record 50 of Set 11 | kupang
# Processing Record 1 of Set 12 | el badari
# City not found. Skipping...
# Processing Record 2 of Set 12 | kavieng
# Processing Record 3 of Set 12 | grand gaube
# Processing Record 4 of Set 12 | kubinka
# Processing Record 5 of Set 12 | avera
# Processing Record 6 of Set 12 | yar-sale
# Processing Record 7 of Set 12 | kutum
# Processing Record 8 of Set 12 | jablah
# Processing Record 9 of Set 12 | saint-francois
# Processing Record 10 of Set 12 | doba
# Processing Record 11 of Set 12 | sinnamary
# Processing Record 12 of Set 12 | kisangani
# Processing Record 13 of Set 12 | sobolevo
# Processing Record 14 of Set 12 | sandwick
# Processing Record 15 of Set 12 | kitakata
# Processing Record 16 of Set 12 | derzhavinsk
# Processing Record 17 of Set 12 | trinidad
# Processing Record 18 of Set 12 | saryozek
# Processing Record 19 of Set 12 | sambava
# Processing Record 20 of Set 12 | konevo
# Processing Record 21 of Set 12 | tela
# Processing Record 22 of Set 12 | zheleznodorozhnyy
# Processing Record 23 of Set 12 | rincon
# Processing Record 24 of Set 12 | bundaberg
# Processing Record 25 of Set 12 | senneterre
# Processing Record 26 of Set 12 | chakrata
# Processing Record 27 of Set 12 | grand-lahou
# Processing Record 28 of Set 12 | karratha
# Processing Record 29 of Set 12 | sayyan
# Processing Record 30 of Set 12 | tutoia
# Processing Record 31 of Set 12 | maku
# Processing Record 32 of Set 12 | hun
# Processing Record 33 of Set 12 | luanda
# Processing Record 34 of Set 12 | lithgow
# Processing Record 35 of Set 12 | bouna
# Processing Record 36 of Set 12 | pacific grove
# Processing Record 37 of Set 12 | ponta pora
# Processing Record 38 of Set 12 | mongar
# Processing Record 39 of Set 12 | port-gentil
# Processing Record 40 of Set 12 | awjilah
# Processing Record 41 of Set 12 | aniva
# Processing Record 42 of Set 12 | darhan
# Processing Record 43 of Set 12 | blagoyevo
# Processing Record 44 of Set 12 | pimentel
# Processing Record 45 of Set 12 | zhengjiatun
# Processing Record 46 of Set 12 | raudeberg
# Processing Record 47 of Set 12 | irtyshskiy
# Processing Record 48 of Set 12 | geraldton
# Processing Record 49 of Set 12 | santa isabel do rio negro
# Processing Record 50 of Set 12 | bambanglipuro
# Processing Record 1 of Set 13 | praia da vitoria
# Processing Record 2 of Set 13 | aurillac
# Processing Record 3 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 13 | calabozo
# Processing Record 5 of Set 13 | shuyskoye
# Processing Record 6 of Set 13 | palaikastron
# Processing Record 7 of Set 13 | selenginsk
# Processing Record 8 of Set 13 | nara
# Processing Record 9 of Set 13 | ngunguru
# Processing Record 10 of Set 13 | nueva guinea
# Processing Record 11 of Set 13 | porbandar
# Processing Record 12 of Set 13 | tibati
# Processing Record 13 of Set 13 | nizwa
# Processing Record 14 of Set 13 | dengzhou
# Processing Record 15 of Set 13 | kunming
# Processing Record 16 of Set 13 | chardara
# Processing Record 17 of Set 13 | jardim
# Processing Record 18 of Set 13 | znamenskoye
# Processing Record 19 of Set 13 | chokwe
# Processing Record 20 of Set 13 | benesov nad ploucnici
# Processing Record 21 of Set 13 | toamasina
# Processing Record 22 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 13 | owando
# Processing Record 24 of Set 13 | kurilsk
# Processing Record 25 of Set 13 | labuhan
# Processing Record 26 of Set 13 | leamington
# Processing Record 27 of Set 13 | riverton
# Processing Record 28 of Set 13 | eregli
# Processing Record 29 of Set 13 | bolitoc
# Processing Record 30 of Set 13 | vila franca do campo
# Processing Record 31 of Set 13 | mahibadhoo
# Processing Record 32 of Set 13 | neiafu
# Processing Record 33 of Set 13 | treinta y tres
# Processing Record 34 of Set 13 | kalemie
# Processing Record 35 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 13 | ahipara
# Processing Record 37 of Set 13 | namatanai
# Processing Record 38 of Set 13 | lumphat
# Processing Record 39 of Set 13 | xining
# Processing Record 40 of Set 13 | puerto madero
# Processing Record 41 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 42 of Set 13 | port augusta
# Processing Record 43 of Set 13 | la ronge
# Processing Record 44 of Set 13 | armidale
# Processing Record 45 of Set 13 | lata
# Processing Record 46 of Set 13 | pangody
# Processing Record 47 of Set 13 | boa vista
# Processing Record 48 of Set 13 | kushiro
# Processing Record 49 of Set 13 | udarnyy
# Processing Record 50 of Set 13 | nenjiang
# Processing Record 1 of Set 14 | bad langensalza
# Processing Record 2 of Set 14 | rodrigues alves
# Processing Record 3 of Set 14 | ingham
# Processing Record 4 of Set 14 | santo tomas
# Processing Record 5 of Set 14 | grootfontein
# Processing Record 6 of Set 14 | jalu
# Processing Record 7 of Set 14 | bhatkal
# Processing Record 8 of Set 14 | biltine
# Processing Record 9 of Set 14 | mhlume
# Processing Record 10 of Set 14 | alice springs
# Processing Record 11 of Set 14 | grindavik
# Processing Record 12 of Set 14 | kayerkan
# Processing Record 13 of Set 14 | agadir
# Processing Record 14 of Set 14 | yaan
# Processing Record 15 of Set 14 | pandan
# Processing Record 16 of Set 14 | soeng sang
# Processing Record 17 of Set 14 | vavuniya
# Processing Record 18 of Set 14 | tubmanburg
# Processing Record 19 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 20 of Set 14 | nabire
# Processing Record 21 of Set 14 | dagda
# Processing Record 22 of Set 14 | mae hong son
# Processing Record 23 of Set 14 | srednekolymsk
# Processing Record 24 of Set 14 | myitkyina
# Processing Record 25 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 14 | strezhevoy
# Processing Record 27 of Set 14 | ouro fino
# Processing Record 28 of Set 14 | axim
# Processing Record 29 of Set 14 | querfurt
# Processing Record 30 of Set 14 | mirnyy
# Processing Record 31 of Set 14 | harrisonburg
# Processing Record 32 of Set 14 | kirakira
# Processing Record 33 of Set 14 | langsa
# Processing Record 34 of Set 14 | gejiu
# Processing Record 35 of Set 14 | clarence town
# Processing Record 36 of Set 14 | chumikan
# Processing Record 37 of Set 14 | cayenne
# Processing Record 38 of Set 14 | livingston
# Processing Record 39 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 14 | ambilobe
# Processing Record 41 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 14 | ritchie
# Processing Record 43 of Set 14 | purranque
# Processing Record 44 of Set 14 | sava
# Processing Record 45 of Set 14 | yokaichi
# Processing Record 46 of Set 14 | fuxin
# Processing Record 47 of Set 14 | mayahi
# Processing Record 48 of Set 14 | baculin
# Processing Record 49 of Set 14 | leh
# Processing Record 50 of Set 14 | eureka
# Processing Record 1 of Set 15 | naze
# Processing Record 2 of Set 15 | pemangkat
# Processing Record 3 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 15 | yerofey pavlovich
# Processing Record 5 of Set 15 | dharmadam
# Processing Record 6 of Set 15 | muros
# Processing Record 7 of Set 15 | makakilo city
# Processing Record 8 of Set 15 | sakakah
# Processing Record 9 of Set 15 | barras
# Processing Record 10 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 15 | serebryansk
# Processing Record 12 of Set 15 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 13 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 14 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 15 | nioro
# Processing Record 16 of Set 15 | makinsk
# Processing Record 17 of Set 15 | villaviciosa
# Processing Record 18 of Set 15 | vardo
# Processing Record 19 of Set 15 | ilo
# Processing Record 20 of Set 15 | kirensk
# Processing Record 21 of Set 15 | pangnirtung
# Processing Record 22 of Set 15 | san ramon
# Processing Record 23 of Set 15 | sungaipenuh
# Processing Record 24 of Set 15 | harnosand
# Processing Record 25 of Set 15 | manavalakurichi
# Processing Record 26 of Set 15 | warrnambool
# Processing Record 27 of Set 15 | jacareacanga
# Processing Record 28 of Set 15 | lugovskoy
# Processing Record 29 of Set 15 | touros
# Processing Record 30 of Set 15 | bandundu
# Processing Record 31 of Set 15 | quattro castella
# Processing Record 32 of Set 15 | outjo
# Processing Record 33 of Set 15 | vadso
# Processing Record 34 of Set 15 | catumbela
# Processing Record 35 of Set 15 | shaoyang
# Processing Record 36 of Set 15 | chunoyar
# Processing Record 37 of Set 15 | balagansk
# Processing Record 38 of Set 15 | contai
# Processing Record 39 of Set 15 | katsuura
# Processing Record 40 of Set 15 | singaparna
# Processing Record 41 of Set 15 | mercedes
# Processing Record 42 of Set 15 | sarahan
# Processing Record 43 of Set 15 | termiz
# Processing Record 44 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 45 of Set 15 | dongobesh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kanigoro      ID  -8.1300  112.2190     77.79        82          96
# 1        Faanui      PF -16.4833 -151.7500     81.61        74          51
# 2     Saskylakh      RU  71.9167  114.0833    -35.52        82          35
# 3  Ponta Do Sol      PT  32.6667  -17.1000     62.60        77          40
# 4        Vesoul      FR  47.5833    5.8333     30.20        93           0
# 5       Lincoln      US  40.8000  -96.6670     18.00        67          90
# 6       Ushuaia      AR -54.8000  -68.3000     39.20        75          75
# 7     Busselton      AU -33.6500  115.3333     70.00        59           1
# 8      Mpulungu      ZM  -8.7623   31.1141     71.08        74          93
# 9     Ekibastuz      KZ  51.6667   75.3667     23.31        96          92
#
#    Wind Speed Current Description
# 0        2.66     overcast clouds
# 1       17.45       broken clouds
# 2        2.04    scattered clouds
# 3        3.44    scattered clouds
# 4        6.91           clear sky
# 5       10.36     overcast clouds
# 6       19.57          light snow
# 7        5.99           clear sky
# 8        3.83          light rain
# 9       16.02     overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
